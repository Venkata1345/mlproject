# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkata1345/mlproject/blob/main/Untitled41.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

video_path = "/content/Original Video MOT17.mp4"  # Change this to your uploaded file name
print(" Video uploaded:", os.path.exists(video_path))
# Out:
#  Video uploaded: True

# %%
# !pip install ultralytics opencv-python numpy pandas torch torchvision lap filterpy
# !git clone https://github.com/mikel-brostrom/Yolov8_DeepSort_Pytorch.git
# %cd Yolov8_DeepSort_Pytorch
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2

# ✅ Load YOLOv8 Model
model = YOLO("yolov8n.pt")  # Use "yolov8s.pt" for better accuracy

# ✅ Open Video File
cap = cv2.VideoCapture(video_path)

# ✅ Get Video Properties
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = int(cap.get(5))

# ✅ Create Output Video Writer
out = cv2.VideoWriter("output_yolo.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # ✅ Run YOLOv8 Object Detection
    results = model(frame)

    # ✅ Draw Bounding Boxes on Frame
    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get box coordinates
            confidence = round(float(box.conf[0]) * 100, 2)
            label = model.names[int(box.cls[0])]

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label} {confidence}%", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # ✅ Write Frame to Output Video
    out.write(frame)

# ✅ Release Resources
cap.release()
out.release()
cv2.destroyAllWindows()
print("✅ Processed video saved as output_yolo.mp4")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 117MB/s]
# 0: 384x640 23 persons, 1 car, 1 motorcycle, 53.4ms
# Speed: 17.5ms preprocess, 53.4ms inference, 371.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 car, 1 motorcycle, 7.1ms
# Speed: 4.7ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 car, 1 motorcycle, 6.9ms
# Speed: 3.4ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 car, 1 motorcycle, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# !pip install ultralytics opencv-python numpy pandas torch torchvision lap filterpy

# %%
# !git clone https://github.com/nwojke/deep_sort.git
# %cd deep_sort
# Out:
# Cloning into 'deep_sort'...
# remote: Enumerating objects: 141, done.
# remote: Total 141 (delta 0), reused 0 (delta 0), pack-reused 141 (from 1)
# Receiving objects: 100% (141/141), 65.59 KiB | 512.00 KiB/s, done.
# Resolving deltas: 100% (78/78), done.
# /content/deep_sort/deep_sort/deep_sort

# %%
import sys
sys.path.append("/content/deep_sort")

# %%
import os
os.chdir("/content/deep_sort")  # Change this to match your repo folder name

# %%
print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/deep_sort/deep_sort/deep_sort

# %%
import sys
sys.path.append(os.getcwd())  # Adds the current directory to Python's path

# %%
from deep_sort.deep_sort.deep_sort tracker import Tracker  # Corrected import

# %%
import os
print(os.listdir("./deep_sort"))
# Out:
# ['nn_matching.py', '__init__.py', 'kalman_filter.py', 'detection.py', 'iou_matching.py', 'tracker.py', 'track.py', '__pycache__', 'linear_assignment.py']

# %%
import os
print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/deep_sort

# %%
os.chdir("/content/deep_sort/deep_sort")  # Change to your actual DeepSORT repo path
print("✅ Changed directory to:", os.getcwd())
# Out:
# ✅ Changed directory to: /content/deep_sort/deep_sort

# %%
import sys
sys.path.append("/content/deep_sort")  # Adjust the path if necessary
sys.path.append("/content/deep_sort/deep_sort")  # Add inner deep_sort folder

# %%
from deep_sort.deep_sort import DeepSort  # Import DeepSORT

# ✅ Initialize DeepSORT Tracker
tracker = DeepSort(max_age=30, n_init=3, nms_max_overlap=1.0)

cap = cv2.VideoCapture(video_path)
out = cv2.VideoWriter("output_tracked.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # ✅ Run YOLOv8 Object Detection
    results = model(frame)
    detections = []

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get box coordinates
            confidence = round(float(box.conf[0]) * 100, 2)
            label = model.names[int(box.cls[0])]
            detections.append(([x1, y1, x2, y2], confidence, label))

    # ✅ Update DeepSORT Tracker
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue
        track_id = track.track_id
        x1, y1, x2, y2 = map(int, track.to_ltrb())

        # ✅ Draw Bounding Box & ID
        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        cv2.putText(frame, f"ID {track_id}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    out.write(frame)

cap.release()
out.release()
cv2.destroyAllWindows()
print("✅ Tracked video saved as output_tracked.mp4")
